# %% [markdown]
# ## Werken met dit notebook
#
# Een notebook bestaat uit tekstcellen en codecellen.
#
# Voer een codecel uit met:
#
# `Shift + Enter`
#
# Als een codecel goed werkt, verschijnt er niet altijd een melding. Soms gebeurt er dus iets zonder dat je output ziet.
#
# Voer de cellen van boven naar beneden uit. Als je het notebook opnieuw opent of de kernel opnieuw start, moet je de importcel opnieuw uitvoeren.

# %% [markdown]
# # ONCT data-analyse opdracht
#
# In deze opdracht gebruik je de ONCT-library en de documentatie om financiële data op te halen, te bekijken en te analyseren.
#
# Gebruik bij iedere stap de ONCT-documentatie of de pandas-handleiding om de juiste functie te vinden en te gebruiken.
#
# Schrijf alleen code in de codecellen.

# %% [markdown]
# # Voorbereiding - functies importeren
#
# Voordat je met de opdracht kunt beginnen, moeten de benodigde functies worden geladen.
#
# Voer de onderstaande cel uit.

# %%
from onct.data import (
    print_json,
    save_json,
    load_json,
    json_to_dataframe,
)

from onct.economie import (
    set_stock_api_key,
    get_stock_quote,
    get_stock_history,
)

import pandas as pd

# %% [markdown]
# # Stap 1 - API key instellen
#
# De functies in `onct.economie` maken gebruik van een externe databron.
#
# Om gegevens uit deze databron op te halen, moet eerst een API key worden ingesteld.
#
# Gebruik de documentatie om je API key in te stellen.
#
# Voer daarna de cel uit.

# %%
# Schrijf hier je code

# %% [markdown]
# # Stap 2 - Actuele koersinformatie ophalen
#
# De actuele koersinformatie bevat gegevens van dit moment, zoals de huidige koers van een aandeel.
#
# Haal de actuele koersinformatie op van het aandeel META.
#
# Sla de opgehaalde JSON-data op in een variabele met de naam `quote`.
#
# Voer daarna de cel uit.

# %%
# Schrijf hier je code

# %% [markdown]
# # Stap 3 - JSON-data bekijken
#
# Bekijk de JSON-data die is opgeslagen in de variabele `quote`.
#
# Gebruik hiervoor een functie uit de module `onct.data`.
#
# Bekijk welke gegevens er in de JSON-data beschikbaar zijn.
#
# Voer daarna de cel uit.

# %%
# Schrijf hier je code

# %% [markdown]
# # Stap 4 - Historische data ophalen
#
# Bij de vorige stap heb je actuele koersinformatie opgehaald.
#
# In deze stap haal je historische koersgegevens op, zodat je de ontwikkeling van de koers over een langere periode kunt analyseren.
#
# Haal historische koersgegevens op van het aandeel META.
#
# Gebruik een periode van 30 dagen.
#
# Sla de opgehaalde JSON-data op in een variabele met de naam `history`.
#
# Voer daarna de cel uit.

# %%
# Schrijf hier je code

# %% [markdown]
# # Stap 5 - Historische data bekijken
#
# Bekijk de JSON-data die is opgeslagen in de variabele `history`.
#
# Gebruik hiervoor een functie uit de module `onct.data`.
#
# Bekijk welke gegevens voor iedere handelsdag beschikbaar zijn.
#
# Voer daarna de cel uit.

# %%
# Schrijf hier je code

# %% [markdown]
# # Stap 6 - JSON-data opslaan
#
# De historische JSON-data wordt opgeslagen in een bestand.
#
# Hierdoor kan de data later opnieuw worden geladen zonder opnieuw een API-aanvraag uit te voeren.
#
# Sla de historische JSON-data uit de variabele `history` op in een bestand.
#
# Gebruik als bestandsnaam:
#
# `meta_history.json`
#
# Voer daarna de cel uit.

# %%
# Schrijf hier je code

# %% [markdown]
# # Stap 7 - JSON-data laden
#
# Laad het bestand `meta_history.json` opnieuw in Python.
#
# Sla de geladen data op in een variabele met de naam `history_loaded`.
#
# Voer daarna de cel uit.

# %%
# Schrijf hier je code

# %% [markdown]
# # Stap 8 - DataFrame maken
#
# Tot nu toe heb je financiële data opgehaald, bekeken, opgeslagen en opnieuw geladen.
#
# Voor het uitvoeren van analyses gebruiken we de Python-library pandas. Deze library is speciaal ontwikkeld voor het werken met tabellen en datasets.
#
# De JSON-data wordt daarom eerst omgezet naar een DataFrame. Een DataFrame kun je zien als een tabel met rijen en kolommen waarop eenvoudig berekeningen en analyses kunnen worden uitgevoerd.
#
# Zet de geladen JSON-data uit de variabele `history_loaded` om naar een pandas DataFrame.
#
# Sla het resultaat op in een variabele met de naam `df`.
#
# Voer daarna de cel uit.

# %%
# Schrijf hier je code

# %% [markdown]
# # Stap 9 - Eerste rijen bekijken
#
# Bekijk de eerste rijen van het DataFrame.
#
# Hierdoor krijg je een eerste indruk van hoe de gegevens in de tabel zijn georganiseerd.
#
# Gebruik de pandas-documentatie om de eerste rijen van het DataFrame te bekijken.
#
# Voer daarna de cel uit.

# %%
# Schrijf hier je code

# %% [markdown]
# # Stap 10 - Kolommen bekijken
#
# Onderzoek welke kolommen aanwezig zijn in het DataFrame.
#
# Deze kolommen bevatten de verschillende gegevens die beschikbaar zijn voor iedere handelsdag.
#
# Gebruik de pandas-documentatie om de kolomnamen te bekijken.
#
# Voer daarna de cel uit.

# %%
# Schrijf hier je code

# %% [markdown]
# # Stap 11 - Gemiddelde slotkoers berekenen
#
# De kolom `close` bevat de slotkoers van iedere handelsdag.
#
# Bereken de gemiddelde waarde van deze kolom.
#
# Gebruik de pandas-documentatie om te onderzoeken hoe je een gemiddelde kunt berekenen.
#
# Voer daarna de cel uit.

# %%
# Schrijf hier je code

# %% [markdown]
# # Stap 12 - Hoogste slotkoers bepalen
#
# De kolom `close` bevat de slotkoers van iedere handelsdag.
#
# Bepaal de hoogste waarde in deze kolom.
#
# Gebruik de pandas-documentatie om te onderzoeken hoe je de hoogste waarde kunt bepalen.
#
# Voer daarna de cel uit.

# %%
# Schrijf hier je code

# %% [markdown]
# # Stap 13 - Laagste slotkoers bepalen
#
# De kolom `close` bevat de slotkoers van iedere handelsdag.
#
# Bepaal de laagste waarde in deze kolom.
#
# Gebruik de pandas-documentatie om te onderzoeken hoe je de laagste waarde kunt bepalen.
#
# Voer daarna de cel uit.

# %%
# Schrijf hier je code

# %% [markdown]
# # Stap 14 - Grafiek maken
#
# De kolom `close` bevat de slotkoers van iedere handelsdag.
#
# Met een grafiek kun je ontwikkelingen en trends vaak sneller herkennen dan in een tabel.
#
# Maak een grafiek van de kolom `close`.
#
# Gebruik de pandas-documentatie om te onderzoeken hoe je een grafiek kunt maken.
#
# Voer daarna de cel uit.

# %%
# Schrijf hier je code

# %% [markdown]
# # Stap 15 - Interpretatie
#
# In de vorige stap heb je een grafiek gemaakt van de historische slotkoersen.
#
# Bekijk deze grafiek.
#
# Beschrijf in 2 tot 3 zinnen wat je opvalt aan de koersontwikkeling van het aandeel.
#
# Je mag hierbij bijvoorbeeld letten op:
#
# - stijgingen;
# - dalingen;
# - schommelingen;
# - opvallende veranderingen.

# %%
# Schrijf je beschrijving:
